# %% [markdown]
# # Versão de tratamento para países e continentes
# O programa abaixo foi tratado para análise detalhada de cada continente e seus respectivos países e posteriormente foi visualizado com auxílio de bibliotecas de criação de gráficos

# %% [markdown]
# # Resumo dos dados

# %% [markdown]
# Ranking de crescimento populacional mundial nos anos de 1970 a 2023
#
# Link da página no Kaggle do dataframe: https://www.kaggle.com/datasets/sazidthe1/world-population-data
#
# *O conjunto primário de dados foi retirado do seguinte site: https://worldpopulationreview.com/

# %% [markdown]
# # Tratamento dos dados

# %% [markdown]
# Importação das bibliotecas necessárias para fazer o tratamento dos dados
#
# *   Pandas: manipulação do dataframe
# *   Numpy: cálculos e operações matemáticas

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Leitura em CSV do arquivo retirado do Kaggle

# %%
df = pd.read_csv("/content/world_population_data.csv")

# %%
df.head(len(df))
# Out:
#      rank cca3           country      continent  2023 population  \
# 0       1  IND             India           Asia       1428627663
# 1       2  CHN             China           Asia       1425671352
# 2       3  USA     United States  North America        339996563
# 3       4  IDN         Indonesia           Asia        277534122
# 4       5  PAK          Pakistan           Asia        240485658
# ..    ...  ...               ...            ...              ...
# 229   230  MSR        Montserrat  North America             4386
# 230   231  FLK  Falkland Islands  South America             3791
# 231   232  NIU              Niue        Oceania             1935
# 232   233  TKL           Tokelau        Oceania             1893
# 233   234  VAT      Vatican City         Europe              518
#
#      2022 population  2020 population  2015 population  2010 population  \
# 0         1417173173       1396387127       1322866505       1240613620
# 1         1425887337       1424929781       1393715448       1348191368
# 2          338289857        335942003        324607776        311182845
# 3          275501339        271857970        259091970        244016173
# 4          235824862        227196741        210969298        194454498
# ..               ...              ...              ...              ...
# 229             4390             4500             5059             4938
# 230             3780             3747             3408             3187
# 231             1934             1942             1847             1812
# 232             1871             1827             1454             1367
# 233              510              520              564              596
#
#      2000 population  1990 population  1980 population  1970 population  \
# 0         1059633675        870452165        696828385        557501301
# 1         1264099069       1153704252        982372466        822534450
# 2          282398554        248083732        223140018        200328340
# 3          214072421        182159874        148177096        115228394
# 4          154369924        115414069         80624057         59290872
# ..               ...              ...              ...              ...
# 229             5138            10805            11452            11402
# 230             3080             2332             2240             2274
# 231             2074             2533             3637             5185
# 232             1666             1669             1647             1714
# 233              651              700              733              752
#
#      area (km²)  density (km²) growth rate world percentage
# 0    3287590.00            481       0.81%           17.85%
# 1    9706961.00            151      -0.02%           17.81%
# 2    9372610.00             37       0.50%            4.25%
# 3    1904569.00            148       0.74%            3.47%
# 4     881912.00            312       1.98%            3.00%
# ..          ...            ...         ...              ...
# 229      102.00             43      -0.09%            0.00%
# 230    12173.00              0       0.29%            0.00%
# 231      261.00              7       0.05%            0.00%
# 232       12.00            189       1.18%            0.00%
# 233        0.44           1177       1.57%            0.00%
#
# [234 rows x 17 columns]

# %%
list(df.columns)
# Out:
# ['rank',
#  'cca3',
#  'country',
#  'continent',
#  '2023 population',
#  '2022 population',
#  '2020 population',
#  '2015 population',
#  '2010 population',
#  '2000 population',
#  '1990 population',
#  '1980 population',
#  '1970 population',
#  'area (km²)',
#  'density (km²)',
#  'growth rate',
#  'world percentage']

# %% [markdown]
# Verificação da quantidade de variação no conteúdo das colunas (a tabela possui 234 linhas)

# %%
for col in df.columns:
  print(f"{col}: {df[col].nunique()}")
# Out:
# rank: 234
# cca3: 234
# country: 234
# continent: 6
# 2023 population: 234
# 2022 population: 234
# 2020 population: 234
# 2015 population: 234
# 2010 population: 234
# 2000 population: 234
# 1990 population: 234
# 1980 population: 234
# 1970 population: 234
# area (km²): 232
# density (km²): 167
# growth rate: 176
# world percentage: 73

# %%
df.isnull().sum()
# Out:
# rank                0
# cca3                0
# country             0
# continent           0
# 2023 population     0
# 2022 population     0
# 2020 population     0
# 2015 population     0
# 2010 population     0
# 2000 population     0
# 1990 population     0
# 1980 population     0
# 1970 population     0
# area (km²)          0
# density (km²)       0
# growth rate         0
# world percentage    0
# dtype: int64

# %% [markdown]
# População global no ano de 2023

# %%
global_pop = df["2023 population"].sum()
print( f'{global_pop:,}')
# Out:
# 8,043,615,390

# %%
df = df.drop(["rank", "cca3", "2022 population", "2020 population", "2015 population", "2010 population", "2000 population", "1990 population", "1980 population", "1970 population", "growth rate"], axis=1)

# %%
df.columns = ["país", "continente", "população (2023)", "área (km²)", "densidade (km²)", "porcentagem mundial"]
print(df.columns)
# Out:
# Index(['país', 'continente', 'população (2023)', 'área (km²)',
#        'densidade (km²)', 'porcentagem mundial'],
#       dtype='object')

# %% [markdown]
# Verificação de tipos das colunas da tabela

# %%
df.dtypes
# Out:
# país                    object
# continente              object
# população (2023)         int64
# área (km²)             float64
# densidade (km²)          int64
# porcentagem mundial     object
# dtype: object

# %% [markdown]
# Identificação da quantidade de continentes presentes na tabela (6)

# %%
continentes = df["continente"].sort_values(ascending=True).unique()
continentes
# Out:
# array(['Africa', 'Asia', 'Europe', 'North America', 'Oceania',
#        'South America'], dtype=object)

# %%
df.keys()
# Out:
# Index(['país', 'continente', 'população (2023)', 'área (km²)',
#        'densidade (km²)', 'porcentagem mundial'],
#       dtype='object')

# %% [markdown]
# Alteração no tipo de dado da coluna "porcentagem mundial" para cálculos

# %%
df["porcentagem mundial"] = df["porcentagem mundial"].str.replace('%', '').astype(float)

# %% [markdown]
# Criação da coluna "porcentagem populacional global" para somar a porcentagem por país e reduzir linhas da tabela
#
# *Foi notado que o resultado da soma das porcentagens passa de 100% (100.49%), por conta disso o resultado não pôde ser analisado visualmente

# %%
df["porcentagem populacional global"] = df.groupby("continente")["porcentagem mundial"].transform("sum")
df["porcentagem populacional global"] = df["porcentagem populacional global"].map("{:.2f}%".format)

# %%
df = df.drop(["porcentagem mundial"], axis=1)

# %% [markdown]
# Criação da coluna de média de área por continente

# %%
df["média de área (km²)"] = df.groupby('continente')['área (km²)'].transform('mean').round(2)

# %% [markdown]
# Criação da coluna de média de densidade por continente que na verdade é uma mediana pois foi notada a presença de um **outlier** que tornou o resultado incorreto

# %%
df["média de densidade (km²)"] = df.groupby('continente')['densidade (km²)'].transform('median').round(2)

# %% [markdown]
# Criação da coluna de média populacional do ano de 2023 por continente

# %%
df_populacao = df.groupby('continente')['população (2023)'].mean().reset_index()
round(df_populacao)
# Out:
#       continente  população (2023)
# 0         Africa        25622394.0
# 1           Asia        95036392.0
# 2         Europe        14837384.0
# 3  North America        15103884.0
# 4        Oceania         1981555.0
# 5  South America        31408501.0

# %%
df = pd.merge(df, round(df_populacao), on='continente', how='left')

# %%
df.head()
# Out:
#             país     continente  população (2023)_x  área (km²)  \
# 0          India           Asia          1428627663   3287590.0
# 1          China           Asia          1425671352   9706961.0
# 2  United States  North America           339996563   9372610.0
# 3      Indonesia           Asia           277534122   1904569.0
# 4       Pakistan           Asia           240485658    881912.0
#
#    densidade (km²) porcentagem populacional global  média de área (km²)  \
# 0              481                          59.37%            642762.88
# 1              151                          59.37%            642762.88
# 2               37                           7.54%            606104.45
# 3              148                          59.37%            642762.88
# 4              312                          59.37%            642762.88
#
#    média de densidade (km²)  população (2023)_y
# 0                   1005.46          95036392.0
# 1                   1005.46          95036392.0
# 2                    274.30          15103884.0
# 3                   1005.46          95036392.0
# 4                   1005.46          95036392.0

# %%
df = df.drop(["população (2023)_x", "área (km²)", "densidade (km²)"], axis=1)

# %%
df = df.rename(columns={"população (2023)_y": "média populacional (2023)"})

# %%
df.dtypes
# Out:
# país                                object
# continente                          object
# porcentagem populacional global     object
# média de área (km²)                float64
# média de densidade (km²)           float64
# média populacional (2023)          float64
# dtype: object

# %% [markdown]
# Agrupamento de países por continente para reduzir linhas da tabela

# %%
df_agrupado = df.groupby('continente')['país'].agg(list).reset_index()
df_agrupado
# Out:
#       continente                                               país
# 0         Africa  [Nigeria, Ethiopia, Egypt, DR Congo, Tanzania,...
# 1           Asia  [India, China, Indonesia, Pakistan, Bangladesh...
# 2         Europe  [Russia, Germany, United Kingdom, France, Ital...
# 3  North America  [United States, Mexico, Canada, Guatemala, Hai...
# 4        Oceania  [Australia, Papua New Guinea, New Zealand, Fij...
# 5  South America  [Brazil, Colombia, Argentina, Peru, Venezuela,...

# %% [markdown]
# Adição do agrupamento na tabela original

# %%
df = pd.merge(df, df_agrupado, on='continente', how='left')

# %%
df = df.drop(["país_x"], axis=1)

# %%
df = df.rename(columns={"país_y": "países"})

# %% [markdown]
# Exclusão de linhas com o mesmo continente para limpeza da tabela

# %%
df = df.drop_duplicates(subset=["continente"])

# %%
df = df.loc[:, ['continente', 'países', 'média populacional (2023)', 'porcentagem populacional global', 'média de área (km²)', 'média de densidade (km²)']]

# %% [markdown]
# Ordenação alfabética da tabela

# %%
df = df.sort_values(by="continente")

# %% [markdown]
# Reset nos indexes que estavam com a ordem da primeira aparição dos países

# %%
df = df.reset_index(drop=True)

# %%
df.head(6)
# Out:
#       continente                                             países  \
# 0         Africa  [Nigeria, Ethiopia, Egypt, DR Congo, Tanzania,...
# 1           Asia  [India, China, Indonesia, Pakistan, Bangladesh...
# 2         Europe  [Russia, Germany, United Kingdom, France, Ital...
# 3  North America  [United States, Mexico, Canada, Guatemala, Hai...
# 4        Oceania  [Australia, Papua New Guinea, New Zealand, Fij...
# 5  South America  [Brazil, Colombia, Argentina, Peru, Venezuela,...
#
#    média populacional (2023) porcentagem populacional global  \
# 0                 25622394.0                          18.27%
# 1                 95036392.0                          59.37%
# 2                 14837384.0                           9.27%
# 3                 15103884.0                           7.54%
# 4                  1981555.0                           0.55%
# 5                 31408501.0                           5.49%
#
#    média de área (km²)  média de densidade (km²)
# 0            531894.09                      70.0
# 1            642762.88                     131.0
# 2            460208.23                     110.0
# 3            606104.45                     224.5
# 4            370226.87                      81.0
# 5           1273813.00                      18.5

# %%
df.to_csv("world_population_cc.csv")

# %% [markdown]
# # Análise dos dados

# %%
import plotly.express as px

# %%
df_graph = df.copy()

df_graph.columns = ['Continente', 'Países', 'Média Populacional (2023)', 'Porcentagem Populacional Global', 'Média de Área (km²)', 'Média de Densidade (km²)']

# %%
fig = px.bar(df_graph.groupby('Continente')['Média Populacional (2023)'].sum().reset_index(name='População'),
             x='Continente',
             y='População',
             color='Continente',
             title='Média Populacional por Continente (2023)',
             height=400,
             width=800)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="73ce3431-0f70-4cf3-b2bf-3cdba483e104" class="plotly-graph-div" style="height:400px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("73ce3431-0f70-4cf3-b2bf-3cdba483e104")) {                    Plotly.newPlot(                        "73ce3431-0f70-4cf3-b2bf-3cdba483e104",                        [{"alignmentgroup":"True","hovertemplate":"Continente=%{x}\u003cbr\u003ePopula\u00e7\u00e3o=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Africa","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Africa","offsetgroup":"Africa","orientation":"v","showlegend":true,"textposition":"auto","x":["Africa"],"xaxis":"x","y":[25622394.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Continente=%{x}\u003cbr\u003ePopula\u00e7\u00e3o=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Asia","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Asia","offsetgroup":"Asia","orientation":"v","showlegend":true,"textposition":"auto","x":["Asia"],"xaxis":"x","y":[95036392.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Continente=%{x}\u003cbr\u003ePopula\u00e7\u00e3o=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Europe","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Europe","offsetgroup":"Europe","orientation":"v","showlegend":true,"textposition":"auto","x":["Europe"],"xaxis":"x","y":[14837384.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Continente=%{x}\u003cbr\u003ePopula\u00e7\u00e3o=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"North America","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"North America","offsetgroup":"North America","orientation":"v","showlegend":true,"textposition":"auto","x":["North America"],"xaxis":"x","y":[15103884.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Continente=%{x}\u003cbr\u003ePopula\u00e7\u00e3o=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Oceania","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Oceania","offsetgroup":"Oceania","orientation":"v","showlegend":true,"textposition":"auto","x":["Oceania"],"xaxis":"x","y":[1981555.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Continente=%{x}\u003cbr\u003ePopula\u00e7\u00e3o=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"South America","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"South America","offsetgroup":"South America","orientation":"v","showlegend":true,"textposition":"auto","x":["South America"],"xaxis":"x","y":[31408501.0],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786" ...

# %%
import matplotlib.pyplot as plt

# %%
fig2 = px.line(df_graph.groupby('Continente')['Média de Área (km²)'].sum().reset_index(name='Área'),
               x='Continente',
               y='Área',
               title='Média de Área (km²) por Continente')
fig2.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="1b2c99de-9452-4df2-afe6-843925779503" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1b2c99de-9452-4df2-afe6-843925779503")) {                    Plotly.newPlot(                        "1b2c99de-9452-4df2-afe6-843925779503",                        [{"hovertemplate":"Continente=%{x}\u003cbr\u003e\u00c1rea=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":["Africa","Asia","Europe","North America","Oceania","South America"],"xaxis":"x","y":[531894.09,642762.88,460208.23,606104.45,370226.87,1273813.0],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type": ...

# %%
fig3 = px.line(df_graph.groupby('Continente')['Média de Densidade (km²)'].sum().reset_index(name='Densidade'),
               x='Continente',
               y='Densidade',
               title='Média de Densidade (km²) por Continente')
fig3.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="edaa416f-c95f-41e0-924c-d2c41e1f73e5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("edaa416f-c95f-41e0-924c-d2c41e1f73e5")) {                    Plotly.newPlot(                        "edaa416f-c95f-41e0-924c-d2c41e1f73e5",                        [{"hovertemplate":"Continente=%{x}\u003cbr\u003eDensidade=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":["Africa","Asia","Europe","North America","Oceania","South America"],"xaxis":"x","y":[70.0,131.0,110.0,224.5,81.0,18.5],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"col ...
